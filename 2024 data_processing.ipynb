# %%
import pandas as pd

# %%
# Importamos el sales df
df_sales = pd.read_csv("Sales TEC_Valid.csv")
df_sales.shape
# Out:
# (2564361, 5)

# %%
# Importamos el flights df
df_flights = pd.read_csv("Filghts TEC_Valid.csv")
df_flights.shape
# Out:
# (245753, 11)

# %%
# Convertir la columna 'STD' a formato datetime si aún no está en ese formato
df_flights['STD'] = pd.to_datetime(df_flights['STD'])

# Filtrar las filas donde el año de 'STD' no es 2024
#df_filtered = df_flights[df_flights['STD'].dt.year != 2023]

# Eliminar filas donde la columna 'Aeronave' tiene valores nulos en el DataFrame filtrado
df_clean_flights = df_flights.dropna(subset=['Aeronave'])

# Ajustar valores de 'Passengers' para que no excedan los de 'Capacity'
df_clean_flights['Passengers'] = df_clean_flights.apply(
    lambda row: min(row['Passengers'], row['Capacity']) if pd.notnull(row['Capacity']) else row['Passengers'],
    axis=1
)
# Out:
# <ipython-input-32-bacbf2b526f8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_flights['Passengers'] = df_clean_flights.apply(

# %%
# Definir las palabras clave a buscar en 'ProductName'
palabras_clave = ['Transfer', 'Taxi', 'Combo', 'Crew', "Vivabus", "Zona", "Vivaplay", "Apto", "Akumal", "Tulum", "Promo","Hoteles","Playa", "Autobuses", "Cancun","Hsbc-Viva","Central","Cat","Hazme"]

# Crear una expresión regular que cubra todas las palabras clave
regex = '|'.join(palabras_clave)  # Esto crea un patrón 'Transfer|Taxi|Combo|Crew|...'

# Filtrar el DataFrame para excluir filas donde 'ProductName' contiene alguna de las palabras clave
# y 'TotalSales' es negativo
df_filtrado_sales = df_sales[
    ~df_sales['ProductName'].str.contains(regex, case=False, na=False) &
    (df_sales['TotalSales'] > 0)
]
df_filtrado_sales
# Out:
#                                 Flight_ID ProductType  \
# 0        a05290288259526edd3601160b10e1de     Botanas
# 1        08f6f97437df8db101b050f1110be656     Licores
# 2        4e09c949826a77207868412baeff6d30     Licores
# 3        c3e1568fe46c68d3174681d322d412b3     Licores
# 5        34ae909bf3699372fcd66f02af0bdd54     Licores
# ...                                   ...         ...
# 2564356  638cf1904f936c50aea4a6f123ee07cf     Licores
# 2564357  04c5a19b8382a888d5c4c7b4932e783e     Licores
# 2564358  0291f6b201d2b24717a8ed7ca04f2d90     Licores
# 2564359  a10e3ac614fd434d6312897e07727c08     Licores
# 2564360  3f53b6ab66d674c6ecec9ebb5d040460     Licores
#
#                        ProductName  Quantity  TotalSales
# 0              Carne Seca Habanero         1        55.0
# 1                    Jw Red Label          2       240.0
# 2                    Jack And Coke         8       576.0
# 3                     Jw Red Label         2       240.0
# 5                      Ron Bacardi         2       240.0
# ...                            ...       ...         ...
# 2564356  Vino Tinto Sangre De Toro         1       155.0
# 2564357  Vino Tinto Sangre De Toro         1       155.0
# 2564358  Vino Tinto Sangre De Toro         1       155.0
# 2564359  Vino Tinto Sangre De Toro         1       155.0
# 2564360  Vino Tinto Sangre De Toro         1       155.0
#
# [2077983 rows x 5 columns]

# %%
# Juntando escalas tomandolas como un mismo vuelo y agarrando max numero de Passengers:

columnas_adicionales = [col for col in df_clean_flights.columns if col not in ['Passengers', 'Flight_ID']]  # Asegúrate de excluir 'Passengers' y 'Flight_ID'

# Agrupar por 'Flight_ID', sumar 'Passengers' y mantener el primer valor encontrado para las otras columnas
result_flights = df_clean_flights.groupby('Flight_ID', as_index=False).agg({  # `as_index=False` mantiene 'Flight_ID' como una columna y no como índice
    'Passengers': 'max',  # Obtener el valor máximo en 'Passengers'
    **{col: 'first' for col in columnas_adicionales}  # Mantener el primer valor para las otras columnas
})

result_flights
# Out:
#                                Flight_ID  Passengers Aeronave  \
# 0       00004a718edba9d9ef878d08f02ae057       174.0   XA-VYD
# 1       0000c5ba279c7225e9f6bac8490678e1         NaN   XA-VBT
# 2       0000cd79c0c3a9c309df6064dcacaeea       186.0   XA-VAR
# 3       00010d4c88e2cb6089937fd4e4f9783b       145.0   XA-VAR
# 4       000158c9b43de5c11cb46d96b0501f2e         NaN   9H-AML
# ...                                  ...         ...      ...
# 160802  ffff138536f249f69340e0a8336f94a4       240.0   XA-VBR
# 160803  ffff1e8f5485017f4c5a6a1919369156         NaN   XA-VIL
# 160804  ffff3393e8b4a4c0c0eec0718a82b564         NaN   9H-MLC
# 160805  ffff782f2ae79e385a016c00fbd994b8       181.0   XA-VAX
# 160806  ffff881a59bc5274e97ea3c4de344e05       162.0   XA-VAI
#
#        DepartureStation ArrivalStation     Destination_Type  \
# 0                    AL             AT     Ciudad Principal
# 1                    AT             BD                Playa
# 2                    AK             AD  MX Amigos y Familia
# 3                    AO             BD                Playa
# 4                    BN             AW     Ciudad Principal
# ...                 ...            ...                  ...
# 160802               AW             AK                Playa
# 160803               AT             AW     Ciudad Principal
# 160804               AR             AO     Ciudad Principal
# 160805               AT             AL  MX Amigos y Familia
# 160806               BH             AO     Ciudad Principal
#
#                 Origin_Type                 STD                  STA  \
# 0       MX Amigos y Familia 2023-12-18 16:20:00  2023-12-18 18:35:00
# 1          Ciudad Principal 2024-03-03 15:10:00  2024-03-03 16:50:00
# 2                     Playa 2023-10-07 18:55:00  2023-10-07 20:30:00
# 3          Ciudad Principal 2023-07-26 13:35:00  2023-07-26 14:30:00
# 4       MX Amigos y Familia 2024-04-23 17:45:00  2024-04-23 19:25:00
# ...                     ...                 ...                  ...
# 160802     Ciudad Principal 2023-06-11 14:00:00  2023-06-11 17:20:00
# 160803     Ciudad Principal 2024-04-23 05:40:00  2024-04-23 07:25:00
# 160804                Playa 2024-03-19 13:25:00  2024-03-19 16:00:00
# 160805     Ciudad Principal 2023-11-06 13:30:00  2023-11-06 15:45:00
# 160806                Playa 2023-03-25 07:55:00  2023-03-25 10:25:00
#
#         Capacity  Bookings
# 0            180     106.0
# 1            220       NaN
# 2            186      93.0
# 3            186      81.0
# 4            178       NaN
# ...          ...       ...
# 160802       240     101.0
# 160803       186       NaN
# 160804       178       NaN
# 160805       186     132.0
# 160806       180     116.0
#
# [160807 rows x 11 columns]

# %% [markdown]
# ## Ruta

# %%
result_flights['Route'] = result_flights['DepartureStation'] + "-" + result_flights['ArrivalStation']
result_flights = result_flights.drop(["DepartureStation","Aeronave", "ArrivalStation"],axis=1)
result_flights
# Out:
#                                Flight_ID  Passengers     Destination_Type  \
# 0       00004a718edba9d9ef878d08f02ae057       174.0     Ciudad Principal
# 1       0000c5ba279c7225e9f6bac8490678e1         NaN                Playa
# 2       0000cd79c0c3a9c309df6064dcacaeea       186.0  MX Amigos y Familia
# 3       00010d4c88e2cb6089937fd4e4f9783b       145.0                Playa
# 4       000158c9b43de5c11cb46d96b0501f2e         NaN     Ciudad Principal
# ...                                  ...         ...                  ...
# 160802  ffff138536f249f69340e0a8336f94a4       240.0                Playa
# 160803  ffff1e8f5485017f4c5a6a1919369156         NaN     Ciudad Principal
# 160804  ffff3393e8b4a4c0c0eec0718a82b564         NaN     Ciudad Principal
# 160805  ffff782f2ae79e385a016c00fbd994b8       181.0  MX Amigos y Familia
# 160806  ffff881a59bc5274e97ea3c4de344e05       162.0     Ciudad Principal
#
#                 Origin_Type                 STD                  STA  \
# 0       MX Amigos y Familia 2023-12-18 16:20:00  2023-12-18 18:35:00
# 1          Ciudad Principal 2024-03-03 15:10:00  2024-03-03 16:50:00
# 2                     Playa 2023-10-07 18:55:00  2023-10-07 20:30:00
# 3          Ciudad Principal 2023-07-26 13:35:00  2023-07-26 14:30:00
# 4       MX Amigos y Familia 2024-04-23 17:45:00  2024-04-23 19:25:00
# ...                     ...                 ...                  ...
# 160802     Ciudad Principal 2023-06-11 14:00:00  2023-06-11 17:20:00
# 160803     Ciudad Principal 2024-04-23 05:40:00  2024-04-23 07:25:00
# 160804                Playa 2024-03-19 13:25:00  2024-03-19 16:00:00
# 160805     Ciudad Principal 2023-11-06 13:30:00  2023-11-06 15:45:00
# 160806                Playa 2023-03-25 07:55:00  2023-03-25 10:25:00
#
#         Capacity  Bookings  Route
# 0            180     106.0  AL-AT
# 1            220       NaN  AT-BD
# 2            186      93.0  AK-AD
# 3            186      81.0  AO-BD
# 4            178       NaN  BN-AW
# ...          ...       ...    ...
# 160802       240     101.0  AW-AK
# 160803       186       NaN  AT-AW
# 160804       178       NaN  AR-AO
# 160805       186     132.0  AT-AL
# 160806       180     116.0  BH-AO
#
# [160807 rows x 9 columns]

# %% [markdown]
# ## Duración

# %%
# Convertir las columnas 'STD' y 'STA' a datetime
result_flights['STD'] = pd.to_datetime(result_flights['STD'])
result_flights['STA'] = pd.to_datetime(result_flights['STA'])

# Extraer la fecha y la hora en columnas separadas
result_flights['Duration'] = result_flights['STA'] - result_flights['STD']
result_flights['Flight_Duration'] = result_flights['Duration'].dt.total_seconds() / 60
result_flights['STD_Date'] = result_flights['STD'].dt.date
result_flights['STD_Time'] = result_flights['STD'].dt.time
result_flights = result_flights.drop(["STA","STD","Duration"],axis=1)
result_flights
# Out:
#                                Flight_ID  Passengers     Destination_Type  \
# 0       00004a718edba9d9ef878d08f02ae057       174.0     Ciudad Principal
# 1       0000c5ba279c7225e9f6bac8490678e1         NaN                Playa
# 2       0000cd79c0c3a9c309df6064dcacaeea       186.0  MX Amigos y Familia
# 3       00010d4c88e2cb6089937fd4e4f9783b       145.0                Playa
# 4       000158c9b43de5c11cb46d96b0501f2e         NaN     Ciudad Principal
# ...                                  ...         ...                  ...
# 160802  ffff138536f249f69340e0a8336f94a4       240.0                Playa
# 160803  ffff1e8f5485017f4c5a6a1919369156         NaN     Ciudad Principal
# 160804  ffff3393e8b4a4c0c0eec0718a82b564         NaN     Ciudad Principal
# 160805  ffff782f2ae79e385a016c00fbd994b8       181.0  MX Amigos y Familia
# 160806  ffff881a59bc5274e97ea3c4de344e05       162.0     Ciudad Principal
#
#                 Origin_Type  Capacity  Bookings  Route  Flight_Duration  \
# 0       MX Amigos y Familia       180     106.0  AL-AT            135.0
# 1          Ciudad Principal       220       NaN  AT-BD            100.0
# 2                     Playa       186      93.0  AK-AD             95.0
# 3          Ciudad Principal       186      81.0  AO-BD             55.0
# 4       MX Amigos y Familia       178       NaN  BN-AW            100.0
# ...                     ...       ...       ...    ...              ...
# 160802     Ciudad Principal       240     101.0  AW-AK            200.0
# 160803     Ciudad Principal       186       NaN  AT-AW            105.0
# 160804                Playa       178       NaN  AR-AO            155.0
# 160805     Ciudad Principal       186     132.0  AT-AL            135.0
# 160806                Playa       180     116.0  BH-AO            150.0
#
#           STD_Date  STD_Time
# 0       2023-12-18  16:20:00
# 1       2024-03-03  15:10:00
# 2       2023-10-07  18:55:00
# 3       2023-07-26  13:35:00
# 4       2024-04-23  17:45:00
# ...            ...       ...
# 160802  2023-06-11  14:00:00
# 160803  2024-04-23  05:40:00
# 160804  2024-03-19  13:25:00
# 160805  2023-11-06  13:30:00
# 160806  2023-03-25  07:55:00
#
# [160807 rows x 10 columns]

# %% [markdown]
# ## Horario del vuelo

# %%
from datetime import datetime, timedelta
result_flights['STD_Time'] = pd.to_datetime(result_flights['STD_Time'], format='%H:%M:%S')

# Función para redondear a la hora más cercana
def round_hour(dt):
    if dt.minute >= 30:
        # Si los minutos son 30 o más, redondear hacia arriba
        dt += timedelta(hours=1)
    return dt.replace(minute=0, second=0)

# Aplicar la función para redondear la hora
result_flights['Hora_Salida_Redondeado'] = result_flights['STD_Time'].apply(round_hour)

# Extraer solo la hora
result_flights['Hora_Salida_Redondeado'] = result_flights['Hora_Salida_Redondeado'].dt.hour

result_flights = result_flights.drop(["STD_Time"],axis=1)
result_flights
# Out:
#                                Flight_ID  Passengers     Destination_Type  \
# 0       00004a718edba9d9ef878d08f02ae057       174.0     Ciudad Principal
# 1       0000c5ba279c7225e9f6bac8490678e1         NaN                Playa
# 2       0000cd79c0c3a9c309df6064dcacaeea       186.0  MX Amigos y Familia
# 3       00010d4c88e2cb6089937fd4e4f9783b       145.0                Playa
# 4       000158c9b43de5c11cb46d96b0501f2e         NaN     Ciudad Principal
# ...                                  ...         ...                  ...
# 160802  ffff138536f249f69340e0a8336f94a4       240.0                Playa
# 160803  ffff1e8f5485017f4c5a6a1919369156         NaN     Ciudad Principal
# 160804  ffff3393e8b4a4c0c0eec0718a82b564         NaN     Ciudad Principal
# 160805  ffff782f2ae79e385a016c00fbd994b8       181.0  MX Amigos y Familia
# 160806  ffff881a59bc5274e97ea3c4de344e05       162.0     Ciudad Principal
#
#                 Origin_Type  Capacity  Bookings  Route  Flight_Duration  \
# 0       MX Amigos y Familia       180     106.0  AL-AT            135.0
# 1          Ciudad Principal       220       NaN  AT-BD            100.0
# 2                     Playa       186      93.0  AK-AD             95.0
# 3          Ciudad Principal       186      81.0  AO-BD             55.0
# 4       MX Amigos y Familia       178       NaN  BN-AW            100.0
# ...                     ...       ...       ...    ...              ...
# 160802     Ciudad Principal       240     101.0  AW-AK            200.0
# 160803     Ciudad Principal       186       NaN  AT-AW            105.0
# 160804                Playa       178       NaN  AR-AO            155.0
# 160805     Ciudad Principal       186     132.0  AT-AL            135.0
# 160806                Playa       180     116.0  BH-AO            150.0
#
#           STD_Date  Hora_Salida_Redondeado
# 0       2023-12-18                      16
# 1       2024-03-03                      15
# 2       2023-10-07                      19
# 3       2023-07-26                      14
# 4       2024-04-23                      18
# ...            ...                     ...
# 160802  2023-06-11                      14
# 160803  2024-04-23                       6
# 160804  2024-03-19                      13
# 160805  2023-11-06                      14
# 160806  2023-03-25                       8
#
# [160807 rows x 10 columns]

# %%
# Asegurar que la columna STD_Date es de tipo datetime
result_flights['STD_Date'] = pd.to_datetime(result_flights['STD_Date'])

# Crear la nueva columna 'Month' extrayendo el mes de la columna 'STD_Date'
result_flights['Month'] = result_flights['STD_Date'].dt.month
result_flights = result_flights[result_flights['STD_Date'].dt.year != 2023]
result_flights = result_flights.drop(["STD_Date"],axis=1)
result_flights
# Out:
#                                Flight_ID  Passengers     Destination_Type  \
# 1       0000c5ba279c7225e9f6bac8490678e1         NaN                Playa
# 4       000158c9b43de5c11cb46d96b0501f2e         NaN     Ciudad Principal
# 12      0005bc7d23da6c5f32537dba8779ad1b         NaN     Ciudad Principal
# 13      0005ccfc27398499603bf18827ddb892         NaN     Ciudad Principal
# 14      0005d2ee26b96255f2a042e01309b9e8         NaN                Playa
# ...                                  ...         ...                  ...
# 160794  fffcab2b9f2830d152d340dd23d4050e         NaN     Ciudad Principal
# 160797  fffd2e563a1bad35b6fbee1cac5fa680         NaN  MX Amigos y Familia
# 160801  fffed485a13460817032edbb8eca9295         NaN     Ciudad Principal
# 160803  ffff1e8f5485017f4c5a6a1919369156         NaN     Ciudad Principal
# 160804  ffff3393e8b4a4c0c0eec0718a82b564         NaN     Ciudad Principal
#
#                 Origin_Type  Capacity  Bookings  Route  Flight_Duration  \
# 1          Ciudad Principal       220       NaN  AT-BD            100.0
# 4       MX Amigos y Familia       178       NaN  BN-AW            100.0
# 12      MX Amigos y Familia       186       NaN  BQ-AW            125.0
# 13         Ciudad Principal       220       NaN  AT-AW            110.0
# 14         Ciudad Principal       230       NaN  AT-BE             75.0
# ...                     ...       ...       ...    ...              ...
# 160794    Ciudad Fronteriza       240       NaN  BM-AO            290.0
# 160797     Ciudad Principal       180       NaN  AW-BF             80.0
# 160801                Playa       230       NaN  AY-BA            160.0
# 160803     Ciudad Principal       186       NaN  AT-AW            105.0
# 160804                Playa       178       NaN  AR-AO            155.0
#
#         Hora_Salida_Redondeado  Month
# 1                           15      3
# 4                           18      4
# 12                          14      4
# 13                          18      3
# 14                          11      4
# ...                        ...    ...
# 160794                       1      2
# 160797                      16      1
# 160801                      14      4
# 160803                       6      4
# 160804                      13      3
#
# [41654 rows x 10 columns]

# %%
result_flights.drop(columns=['Flight_ID'])
result_flights
# Out:
#                                Flight_ID  Passengers     Destination_Type  \
# 1       0000c5ba279c7225e9f6bac8490678e1         NaN                Playa
# 4       000158c9b43de5c11cb46d96b0501f2e         NaN     Ciudad Principal
# 12      0005bc7d23da6c5f32537dba8779ad1b         NaN     Ciudad Principal
# 13      0005ccfc27398499603bf18827ddb892         NaN     Ciudad Principal
# 14      0005d2ee26b96255f2a042e01309b9e8         NaN                Playa
# ...                                  ...         ...                  ...
# 160794  fffcab2b9f2830d152d340dd23d4050e         NaN     Ciudad Principal
# 160797  fffd2e563a1bad35b6fbee1cac5fa680         NaN  MX Amigos y Familia
# 160801  fffed485a13460817032edbb8eca9295         NaN     Ciudad Principal
# 160803  ffff1e8f5485017f4c5a6a1919369156         NaN     Ciudad Principal
# 160804  ffff3393e8b4a4c0c0eec0718a82b564         NaN     Ciudad Principal
#
#                 Origin_Type  Capacity  Bookings  Route  Flight_Duration  \
# 1          Ciudad Principal       220       NaN  AT-BD            100.0
# 4       MX Amigos y Familia       178       NaN  BN-AW            100.0
# 12      MX Amigos y Familia       186       NaN  BQ-AW            125.0
# 13         Ciudad Principal       220       NaN  AT-AW            110.0
# 14         Ciudad Principal       230       NaN  AT-BE             75.0
# ...                     ...       ...       ...    ...              ...
# 160794    Ciudad Fronteriza       240       NaN  BM-AO            290.0
# 160797     Ciudad Principal       180       NaN  AW-BF             80.0
# 160801                Playa       230       NaN  AY-BA            160.0
# 160803     Ciudad Principal       186       NaN  AT-AW            105.0
# 160804                Playa       178       NaN  AR-AO            155.0
#
#         Hora_Salida_Redondeado  Month
# 1                           15      3
# 4                           18      4
# 12                          14      4
# 13                          18      3
# 14                          11      4
# ...                        ...    ...
# 160794                       1      2
# 160797                      16      1
# 160801                      14      4
# 160803                       6      4
# 160804                      13      3
#
# [41654 rows x 10 columns]

# %%
result_flights.to_csv('sales_24.csv', index=False)

# %% [markdown]
# ## Preprocesando df_filtrado_sales

# %%
# Borrando variable ProductType
df_filtrado_sales=df_filtrado_sales.drop(["ProductType"],axis=1)
df_filtrado_sales
# Out:
#                                 Flight_ID                ProductName  \
# 0        a05290288259526edd3601160b10e1de        Carne Seca Habanero
# 1        08f6f97437df8db101b050f1110be656              Jw Red Label
# 2        4e09c949826a77207868412baeff6d30              Jack And Coke
# 3        c3e1568fe46c68d3174681d322d412b3               Jw Red Label
# 5        34ae909bf3699372fcd66f02af0bdd54                Ron Bacardi
# ...                                   ...                        ...
# 2564356  638cf1904f936c50aea4a6f123ee07cf  Vino Tinto Sangre De Toro
# 2564357  04c5a19b8382a888d5c4c7b4932e783e  Vino Tinto Sangre De Toro
# 2564358  0291f6b201d2b24717a8ed7ca04f2d90  Vino Tinto Sangre De Toro
# 2564359  a10e3ac614fd434d6312897e07727c08  Vino Tinto Sangre De Toro
# 2564360  3f53b6ab66d674c6ecec9ebb5d040460  Vino Tinto Sangre De Toro
#
#          Quantity  TotalSales
# 0               1        55.0
# 1               2       240.0
# 2               8       576.0
# 3               2       240.0
# 5               2       240.0
# ...           ...         ...
# 2564356         1       155.0
# 2564357         1       155.0
# 2564358         1       155.0
# 2564359         1       155.0
# 2564360         1       155.0
#
# [2077983 rows x 4 columns]

# %%
pivot_df = df_filtrado_sales.pivot_table(
    index='Flight_ID',
    columns='ProductName',
    values='Quantity',
    aggfunc='sum',
    fill_value=0
)
pivot_df
# Out:
# ProductName                       Agua Natural 600 Ml  Amstel Ultra  Arandano  \
# Flight_ID
# 00004a718edba9d9ef878d08f02ae057                    4             0         0
# 0000cd79c0c3a9c309df6064dcacaeea                    2             0         0
# 000163f0df9cbfc35c4c06645ec512f6                    0             0         0
# 00017be73003a570dd426b155762769c                    8             0         0
# 0001a43836c338f8d8650aefb11672c9                    3             0         0
# ...                                               ...           ...       ...
# fffe47f84ecc55da94b2907a7317dd12                   15             0         0
# fffe4a9c19ae2320e76f02939fdff957                    4             4         0
# ffff138536f249f69340e0a8336f94a4                    5             0         0
# ffff782f2ae79e385a016c00fbd994b8                    3             0         0
# ffff881a59bc5274e97ea3c4de344e05                    0             0         0
#
# ProductName                       Arandano Mango Mix  Arcoiris  Baileys  \
# Flight_ID
# 00004a718edba9d9ef878d08f02ae057                   0         0        0
# 0000cd79c0c3a9c309df6064dcacaeea                   0         0        0
# 000163f0df9cbfc35c4c06645ec512f6                   0         0        0
# 00017be73003a570dd426b155762769c                   1         0        0
# 0001a43836c338f8d8650aefb11672c9                   2         0        2
# ...                                              ...       ...      ...
# fffe47f84ecc55da94b2907a7317dd12                   0         1        0
# fffe4a9c19ae2320e76f02939fdff957                   0         0        0
# ffff138536f249f69340e0a8336f94a4                   3         0        0
# ffff782f2ae79e385a016c00fbd994b8                   0         0        0
# ffff881a59bc5274e97ea3c4de344e05                   0         0        0
#
# ProductName                       Baileys   Cafe 19 Cafe Clasico  \
# Flight_ID
# 00004a718edba9d9ef878d08f02ae